# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, KBinsDiscretizer
from pgmpy.models import DiscreteBayesianNetwork
from pgmpy.estimators import HillClimbSearch, BayesianEstimator
from pgmpy.inference import VariableElimination

# %%
df_ckd = df = pd.read_csv('../data/ckd_clean.csv')

# %%
target = 'Class'

# %%
df_encoded = df.copy()
categorical_cols = df.select_dtypes(include='object').columns

for col in categorical_cols:
    df_encoded[col] = LabelEncoder().fit_transform(df[col].astype(str))

# %%
numerical_cols = df_encoded.select_dtypes(include = ['int64', 'float64']).drop(columns = [target]).columns
discretizer = KBinsDiscretizer(n_bins = 3, encode = 'ordinal', strategy = 'uniform')
df_encoded[numerical_cols] = discretizer.fit_transform(df_encoded[numerical_cols])
df_encoded = df_encoded.astype(int)
df_encoded.head()
# Out:
# C:\Users\angel\anaconda3\Lib\site-packages\sklearn\preprocessing\_discretization.py:248: FutureWarning: In version 1.5 onwards, subsample=200_000 will be used by default. Set subsample explicitly to silence this warning in the mean time. Set subsample=None to disable subsampling explicitly.
#   warnings.warn(
#    Age  Blood Pressure  Specific Gravity  Albumin  Sugar  Red Blood Cells  \
# 0    1               1                 0        2      0                1
# 1    1               2                 2        1      0                0
# 2    2               1                 0        2      0                0
# 3    2               1                 0        2      1                1
# 4    2               1                 1        1      0                0
#
#    Pus Cell  Pus Cell clumps  Bacteria  Blood Glucose Random  ...  \
# 0         0                1         0                     0  ...
# 1         0                1         0                     0  ...
# 2         0                1         0                     2  ...
# 3         0                1         1                     0  ...
# 4         0                0         0                     0  ...
#
#    Packed Cell Volume  White Blood Cell Count  Red Blood Cell Count  \
# 0                   1                       0                     0
# 1                   1                       1                     0
# 2                   1                       0                     0
# 3                   0                       0                     0
# 4                   1                       0                     0
#
#    Hypertension  Diabetes Mellitus  Coronary Artery Disease  Appetite  \
# 0             1                  0                        0         1
# 1             1                  1                        0         1
# 2             1                  1                        0         1
# 3             1                  1                        1         1
# 4             1                  1                        1         1
#
#    Pedal Edema  Anemia  Class
# 0            1       1      1
# 1            0       1      1
# 2            1       0      1
# 3            1       0      1
# 4            1       1      1
#
# [5 rows x 25 columns]

# %%
hc = HillClimbSearch(df_encoded)
best_model = hc.estimate()
print("Learned edges", best_model.edges())
# Out:
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'Age': 'N', 'Blood Pressure': 'N', 'Specific Gravity': 'N', 'Albumin': 'N', 'Sugar': 'N', 'Red Blood Cells': 'N', 'Pus Cell': 'N', 'Pus Cell clumps': 'N', 'Bacteria': 'N', 'Blood Glucose Random': 'N', 'Blood Urea': 'N', 'Serum Creatinine': 'N', 'Sodium': 'N', 'Potassium': 'N', 'Hemoglobin': 'N', 'Packed Cell Volume': 'N', 'White Blood Cell Count': 'N', 'Red Blood Cell Count': 'N', 'Hypertension': 'N', 'Diabetes Mellitus': 'N', 'Coronary Artery Disease': 'N', 'Appetite': 'N', 'Pedal Edema': 'N', 'Anemia': 'N', 'Class': 'N'}
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'Age': 'N', 'Blood Pressure': 'N', 'Specific Gravity': 'N', 'Albumin': 'N', 'Sugar': 'N', 'Red Blood Cells': 'N', 'Pus Cell': 'N', 'Pus Cell clumps': 'N', 'Bacteria': 'N', 'Blood Glucose Random': 'N', 'Blood Urea': 'N', 'Serum Creatinine': 'N', 'Sodium': 'N', 'Potassium': 'N', 'Hemoglobin': 'N', 'Packed Cell Volume': 'N', 'White Blood Cell Count': 'N', 'Red Blood Cell Count': 'N', 'Hypertension': 'N', 'Diabetes Mellitus': 'N', 'Coronary Artery Disease': 'N', 'Appetite': 'N', 'Pedal Edema': 'N', 'Anemia': 'N', 'Class': 'N'}
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'Age': 'N', 'Blood Pressure': 'N', 'Specific Gravity': 'N', 'Albumin': 'N', 'Sugar': 'N', 'Red Blood Cells': 'N', 'Pus Cell': 'N', 'Pus Cell clumps': 'N', 'Bacteria': 'N', 'Blood Glucose Random': 'N', 'Blood Urea': 'N', 'Serum Creatinine': 'N', 'Sodium': 'N', 'Potassium': 'N', 'Hemoglobin': 'N', 'Packed Cell Volume': 'N', 'White Blood Cell Count': 'N', 'Red Blood Cell Count': 'N', 'Hypertension': 'N', 'Diabetes Mellitus': 'N', 'Coronary Artery Disease': 'N', 'Appetite': 'N', 'Pedal Edema': 'N', 'Anemia': 'N', 'Class': 'N'}
#   0%|          | 0/1000000 [00:00<?, ?it/s]
# Learned edges [('Specific Gravity', 'Bacteria'), ('Serum Creatinine', 'Blood Urea'), ('Hemoglobin', 'Packed Cell Volume'), ('Hemoglobin', 'Class'), ('Hemoglobin', 'Pus Cell'), ('Packed Cell Volume', 'Anemia'), ('Red Blood Cell Count', 'Serum Creatinine'), ('Red Blood Cell Count', 'Pus Cell clumps'), ('Hypertension', 'Coronary Artery Disease'), ('Hypertension', 'Sugar'), ('Hypertension', 'Age'), ('Class', 'Albumin'), ('Class', 'Specific Gravity'), ('Class', 'Hypertension'), ('Class', 'Red Blood Cell Count'), ('Class', 'Diabetes Mellitus'), ('Class', 'Pedal Edema'), ('Class', 'Appetite'), ('Class', 'Sodium'), ('Class', 'Blood Glucose Random'), ('Class', 'Red Blood Cells'), ('Class', 'Blood Pressure'), ('Class', 'White Blood Cell Count')]

# %%
model = DiscreteBayesianNetwork(best_model.edges())
model.fit(df_encoded, estimator = BayesianEstimator, prior_type = 'BDeu')
# Out:
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'Age': 'N', 'Blood Pressure': 'N', 'Specific Gravity': 'N', 'Albumin': 'N', 'Sugar': 'N', 'Red Blood Cells': 'N', 'Pus Cell': 'N', 'Pus Cell clumps': 'N', 'Bacteria': 'N', 'Blood Glucose Random': 'N', 'Blood Urea': 'N', 'Serum Creatinine': 'N', 'Sodium': 'N', 'Potassium': 'N', 'Hemoglobin': 'N', 'Packed Cell Volume': 'N', 'White Blood Cell Count': 'N', 'Red Blood Cell Count': 'N', 'Hypertension': 'N', 'Diabetes Mellitus': 'N', 'Coronary Artery Disease': 'N', 'Appetite': 'N', 'Pedal Edema': 'N', 'Anemia': 'N', 'Class': 'N'}

# %%
inference = VariableElimination(model)
result = inference.query(variables=['Class'], evidence={
    'Blood Glucose Random': 2,
    'Albumin': 1,
    'Appetite': 0,
    'Hypertension': 1,
    'Packed Cell Volume': 2,
    'Age': 2,
})
print("Probability of disease given symptoms:")
print(result)
# Out:
# Probability of disease given symptoms:
# +----------+--------------+
# | Class    |   phi(Class) |
# +==========+==============+
# | Class(0) |       0.0016 |
# +----------+--------------+
# | Class(1) |       0.9984 |
# +----------+--------------+

# %%
print(model.get_cpds('Class'))
# Out:
# +------------+---------------------+-----+----------------------+
# | Hemoglobin | Hemoglobin(0)       | ... | Hemoglobin(2)        |
# +------------+---------------------+-----+----------------------+
# | Class(0)   | 0.09615384615384616 | ... | 0.976123595505618    |
# +------------+---------------------+-----+----------------------+
# | Class(1)   | 0.9038461538461539  | ... | 0.023876404494382025 |
# +------------+---------------------+-----+----------------------+

# %%
for cpd in model.get_cpds():
    print(cpd)
# Out:
# +---------------------+----------------------+---------------------+
# | Class               | Class(0)             | Class(1)            |
# +---------------------+----------------------+---------------------+
# | Specific Gravity(0) | 0.007092198581560284 | 0.5897435897435898  |
# +---------------------+----------------------+---------------------+
# | Specific Gravity(1) | 0.007092198581560284 | 0.2380952380952381  |
# +---------------------+----------------------+---------------------+
# | Specific Gravity(2) | 0.9858156028368794   | 0.17216117216117216 |
# +---------------------+----------------------+---------------------+
# +------------------+-----+----------------------+
# | Specific Gravity | ... | Specific Gravity(2)  |
# +------------------+-----+----------------------+
# | Bacteria(0)      | ... | 0.9932614555256065   |
# +------------------+-----+----------------------+
# | Bacteria(1)      | ... | 0.006738544474393532 |
# +------------------+-----+----------------------+
# +----------------------+-----+-------------------------+
# | Red Blood Cell Count | ... | Red Blood Cell Count(2) |
# +----------------------+-----+-------------------------+
# | Serum Creatinine(0)  | ... | 0.9487179487179486      |
# +----------------------+-----+-------------------------+
# | Serum Creatinine(1)  | ... | 0.025641025641025637    |
# +----------------------+-----+-------------------------+
# | Serum Creatinine(2)  | ... | 0.025641025641025637    |
# +----------------------+-----+-------------------------+
# +------------------+-----+---------------------+
# | Serum Creatinine | ... | Serum Creatinine(2) |
# +------------------+-----+---------------------+
# | Blood Urea(0)    | ... | 0.0574712643678161  |
# +------------------+-----+---------------------+
# | Blood Urea(1)    | ... | 0.5747126436781609  |
# +------------------+-----+---------------------+
# | Blood Urea(2)    | ... | 0.367816091954023   |
# +------------------+-----+---------------------+
# +---------------+-----------+
# | Hemoglobin(0) | 0.0531697 |
# +---------------+-----------+
# | Hemoglobin(1) | 0.218814  |
# +---------------+-----------+
# | Hemoglobin(2) | 0.728016  |
# +---------------+-----------+
# +-----------------------+-----+-----------------------+
# | Hemoglobin            | ... | Hemoglobin(2)         |
# +-----------------------+-----+-----------------------+
# | Packed Cell Volume(0) | ... | 0.0046816479400749065 |
# +-----------------------+-----+-----------------------+
# | Packed Cell Volume(1) | ... | 0.0046816479400749065 |
# +-----------------------+-----+-----------------------+
# | Packed Cell Volume(2) | ... | 0.9906367041198502    |
# +-----------------------+-----+-----------------------+
# +------------+---------------------+-----+----------------------+
# | Hemoglobin | Hemoglobin(0)       | ... | Hemoglobin(2)        |
# +------------+---------------------+-----+----------------------+
# | Class(0)   | 0.09615384615384616 | ... | 0.976123595505618    |
# +------------+---------------------+-----+----------------------+
# | Class(1)   | 0.9038461538461539  | ... | 0.023876404494382025 |
# +------------+---------------------+-----+----------------------+
# +-------------+---------------------+--------------------+---------------------+
# | Hemoglobin  | Hemoglobin(0)       | Hemoglobin(1)      | Hemoglobin(2)       |
# +-------------+---------------------+--------------------+---------------------+
# | Pus Cell(0) | 0.7884615384615384  | 0.6682242990654206 | 0.00702247191011236 |
# +-------------+---------------------+--------------------+---------------------+
# | Pus Cell(1) | 0.21153846153846156 | 0.3317757009345795 | 0.9929775280898877  |
# +-------------+---------------------+--------------------+---------------------+
# +--------------------+-----+-----------------------+
# | Packed Cell Volume | ... | Packed Cell Volume(2) |
# +--------------------+-----+-----------------------+
# | Anemia(0)          | ... | 0.9930362116991643    |
# +--------------------+-----+-----------------------+
# | Anemia(1)          | ... | 0.006963788300835655  |
# +--------------------+-----+-----------------------+
# +------------+----------------------+---------------------+
# | Class      | Class(0)             | Class(1)            |
# +------------+----------------------+---------------------+
# | Albumin(0) | 0.9858156028368795   | 0.10622710622710622 |
# +------------+----------------------+---------------------+
# | Albumin(1) | 0.007092198581560285 | 0.21611721611721613 |
# +------------+----------------------+---------------------+
# | Albumin(2) | 0.007092198581560285 | 0.6776556776556776  |
# +------------+----------------------+---------------------+
# +-----------------+----------------------+---------------------+
# | Class           | Class(0)             | Class(1)            |
# +-----------------+----------------------+---------------------+
# | Hypertension(0) | 0.9893617021276596   | 0.22527472527472528 |
# +-----------------+----------------------+---------------------+
# | Hypertension(1) | 0.010638297872340425 | 0.7747252747252747  |
# +-----------------+----------------------+---------------------+
# +-------------------------+----------------------+---------------------+
# | Class                   | Class(0)             | Class(1)            |
# +-------------------------+----------------------+---------------------+
# | Red Blood Cell Count(0) | 0.007092198581560285 | 0.7216117216117216  |
# +-------------------------+----------------------+---------------------+
# | Red Blood Cell Count(1) | 0.824113475177305    | 0.23809523809523808 |
# +-------------------------+----------------------+---------------------+
# | Red Blood Cell Count(2) | 0.16879432624113477  | 0.04029304029304029 |
# +-------------------------+----------------------+---------------------+
# +----------------------+----------------------+---------------------+
# | Class                | Class(0)             | Class(1)            |
# +----------------------+----------------------+---------------------+
# | Diabetes Mellitus(0) | 0.9893617021276596   | 0.35714285714285715 |
# +----------------------+----------------------+---------------------+
# | Diabetes Mellitus(1) | 0.010638297872340425 | 0.6428571428571429  |
# +----------------------+----------------------+---------------------+
# +----------------+----------------------+---------------------+
# | Class          | Class(0)             | Class(1)            |
# +----------------+----------------------+---------------------+
# | Pedal Edema(0) | 0.9893617021276596   | 0.532967032967033   |
# +----------------+----------------------+---------------------+
# | Pedal Edema(1) | 0.010638297872340425 | 0.46703296703296704 |
# +----------------+----------------------+---------------------+
# +-------------+----------------------+---------------------+
# | Class       | Class(0)             | Class(1)            |
# +-------------+----------------------+---------------------+
# | Appetite(0) | 0.9893617021276596   | 0.554945054945055   |
# +-------------+----------------------+---------------------+
# | Appetite(1) | 0.010638297872340425 | 0.44505494505494503 |
# +-------------+----------------------+---------------------+
# +-----------+----------------------+---------------------+
# | Class     | Class(0)             | Class(1)            |
# +-----------+----------------------+---------------------+
# | Sodium(0) | 0.007092198581560284 | 0.19413919413919414 |
# +-----------+----------------------+---------------------+
# | Sodium(1) | 0.17730496453900707  | 0.5897435897435898  |
# +-----------+----------------------+---------------------+
# | Sodium(2) | 0.8156028368794326   | 0.21611721611721613 |
# +-----------+----------------------+---------------------+
# +-------------------------+----------------------+---------------------+
# | Class                   | Class(0)             | Class(1)            |
# +-------------------------+----------------------+---------------------+
# | Blood Glucose Random(0) | 0.9858156028368795   | 0.5238095238095238  |
# +-------------------------+----------------------+---------------------+
# | Blood Glucose Random(1) | 0.007092198581560285 | 0.39194139194139194 |
# +-------------------------+----------------------+---------------------+
# | Blood Glucose Random(2) | 0.007092198581560285 | 0.08424908424908426 |
# +-------------------------+----------------------+---------------------+
# +--------------------+----------------------+--------------------+
# | Class              | Class(0)             | Class(1)           |
# +--------------------+----------------------+--------------------+
# | Red Blood Cells(0) | 0.010638297872340425 | 0.4230769230769231 |
# +--------------------+----------------------+--------------------+
# | Red Blood Cells(1) | 0.9893617021276596   | 0.5769230769230769 |
# +--------------------+----------------------+--------------------+
# +-------------------+----------------------+---------------------+
# | Class             | Class(0)             | Class(1)            |
# +-------------------+----------------------+---------------------+
# | Blood Pressure(0) | 0.30496453900709225  | 0.15018315018315018 |
# +-------------------+----------------------+---------------------+
# | Blood Pressure(1) | 0.6879432624113475   | 0.45787545787545786 |
# +-------------------+----------------------+---------------------+
# | Blood Pressure(2) | 0.007092198581560285 | 0.39194139194139194 |
# +-------------------+----------------------+---------------------+
# +---------------------------+----------------------+---------------------+
# | Class                     | Class(0)             | Class(1)            |
# +---------------------------+----------------------+---------------------+
# | White Blood Cell Count(0) | 0.9858156028368795   | 0.6117216117216117  |
# +---------------------------+----------------------+---------------------+
# | White Blood Cell Count(1) | 0.007092198581560285 | 0.30402930402930406 |
# +---------------------------+----------------------+---------------------+
# | White Blood Cell Count(2) | 0.007092198581560285 | 0.08424908424908426 |
# +---------------------------+----------------------+---------------------+
# +----------------------+-----+-------------------------+
# | Red Blood Cell Count | ... | Red Blood Cell Count(2) |
# +----------------------+-----+-------------------------+
# | Pus Cell clumps(0)   | ... | 0.9615384615384616      |
# +----------------------+-----+-------------------------+
# | Pus Cell clumps(1)   | ... | 0.03846153846153847     |
# +----------------------+-----+-------------------------+
# +----------------------------+----------------------+--------------------+
# | Hypertension               | Hypertension(0)      | Hypertension(1)    |
# +----------------------------+----------------------+--------------------+
# | Coronary Artery Disease(0) | 0.9901185770750988   | 0.6643835616438356 |
# +----------------------------+----------------------+--------------------+
# | Coronary Artery Disease(1) | 0.009881422924901186 | 0.3356164383561644 |
# +----------------------------+----------------------+--------------------+
# +--------------+----------------------+---------------------+
# | Hypertension | Hypertension(0)      | Hypertension(1)     |
# +--------------+----------------------+---------------------+
# | Sugar(0)     | 0.9868247694334652   | 0.6255707762557078  |
# +--------------+----------------------+---------------------+
# | Sugar(1)     | 0.006587615283267458 | 0.26940639269406397 |
# +--------------+----------------------+---------------------+
# | Sugar(2)     | 0.006587615283267458 | 0.10502283105022832 |
# +--------------+----------------------+---------------------+
# +--------------+---------------------+----------------------+
# | Hypertension | Hypertension(0)     | Hypertension(1)      |
# +--------------+---------------------+----------------------+
# | Age(0)       | 0.18050065876152832 | 0.022831050228310504 |
# +--------------+---------------------+----------------------+
# | Age(1)       | 0.544137022397892   | 0.35159817351598177  |
# +--------------+---------------------+----------------------+
# | Age(2)       | 0.2753623188405797  | 0.6255707762557078   |
# +--------------+---------------------+----------------------+
